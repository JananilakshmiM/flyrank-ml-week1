# %% [markdown]
# <a href="https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# :## 1. Unit of analysis + time window### Unit of Analysis + Time Window
#
# One row represents one content page's search performance record over a specific analysis period.
#
# For this analysis, I will use historical data from a mid-panel time window (for example, March 2026) to understand page performance patterns.
#
# The unit of analysis is a page-level record because the goal is to rank pages for optimization opportunities.
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
# ### Fields Classification
#
# **Features:**
# - impressions: shows search visibility of a page.
# - clicks: shows user interactions.
# - CTR: measures click efficiency.
# - avg_position: represents search ranking position.
# - content_type: describes the type of page content.
#
# **Label / Proxy:**
# - Optimization priority score or improvement opportunity indicator.
#
# **Context:**
# - Date information
# - Page metadata
# - Search performance information
#
# **Excluded:**
# - Future outcome information because it would not be available at decision time and could cause data leakage.
# - Private client information because it should not be included in analysis.
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
# ### Data Verification
#
# I will verify the data contract using queries that check:
#
# - The grain of the dataset (what one row represents).
# - The number of available records.
# - Missing values in important fields.
# - The available date range.
#
# These checks ensure that the assumptions about the dataset are measured from the actual data.
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
# ### Data Limitations
#
# This dataset cannot explain every reason behind search performance changes.
#
# Limitations include:
# - Historical data may not represent future search behaviour.
# - Some early records may have incomplete Search Console data.
# - Overlapping time windows may affect comparisons.
#
# The results should be considered observed patterns and decision-support insights, not causal proof.
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
