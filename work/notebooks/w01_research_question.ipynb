# %% [markdown]
# <a href="https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane: Freestyle
#
# I chose the **Freestyle** lane because it allows me to explore search and content performance from different perspectives while applying machine learning concepts. My goal is to understand how content quality, search position, and user engagement influence search performance, and to use data-driven insights to support better content decisions. This lane gives me the flexibility to test different ideas and build practical ML skills throughout the internship.## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*## Decision, Action, and Cost of a Wrong Recommendation
#
# **Decision:** My work helps identify which content should be prioritised for optimisation to improve search performance.
#
# **Who acts on it?** A content manager or SEO specialist reviews the recommendations and decides which pages should be updated based on the model's output.
#
# **Cost of a wrong recommendation:** An incorrect recommendation may result in improving low-priority content while important pages are ignored. This can waste time and resources, reduce search performance, and delay business improvements. Therefore, the recommendations should be used as **decision support** and confirmed through human review before implementation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*### Quick Look at the Data
#
# From the starter dataset:
#
# - The dataset contains **<total_rows>** records.
# - The average click-through rate (CTR) is **<average_ctr>%**.
# - The average search position is **<average_position>**.
#
# These initial statistics suggest that the dataset contains enough variation to study the relationship between search performance and content characteristics over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# [link text](https://)## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, ### Careful Words: What I Can and Can't Claim
#
# This work can identify **observed patterns**, **directional relationships**, and provide **decision-support** recommendations based on the available data. The results can help content managers prioritise actions and guide further analysis.
#
# This work **cannot** prove that one factor directly causes another, predict Google's search algorithm, or guarantee future search rankings. The recommendations are based on historical data and should always be reviewed by a human before implementation.decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
