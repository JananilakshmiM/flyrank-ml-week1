# %% [markdown]
# <a href="https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w04_baseline_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JananilakshmiM/flyrank-ml-week1/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes## My Rule and Reason Codes
#
# ### Baseline Rule
#
# I will prioritize pages that have **high search impressions** but **low click-through rate (CTR)**. These pages already receive visibility in search results, so improving titles, meta descriptions, or content may increase user engagement.
#
# ### Reason Codes
#
# - **LOW_CTR_HIGH_IMPRESSIONS** – The page receives many impressions but has a relatively low CTR.
# - **LOW_VISIBILITY** – The page has low impressions and may require monitoring rather than immediate action.
# - **HIGH_PRIORITY_REVIEW** – The page shows strong potential for improvement and should be reviewed first.
#
# ### Action Labels
#
# - Refresh Content
# - Review Metadata
# - Monitor
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
# ## Ranked Queue
#
# The baseline score is calculated using historical search signals such as impressions and CTR.
#
# Pages with high impressions and low CTR receive higher scores because they may provide greater opportunities for improvement.
#
# The ranked queue includes:
# - Opportunity Score
# - Reason Code
# - Recommended Action
#
# The notebook writes the ranked results to:
#
# `work/outputs/baseline_action_score.csv`
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Top-20 review
# ## Top-20 Review
#
# | Rank | Action | Reason Code | Confidence | What would make it wrong? |
# |------|--------|-------------|------------|----------------------------|
# | 1 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Seasonal traffic patterns |
# | 2 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Recently updated content |
# | 3 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | Search intent changed |
# | 4 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Temporary ranking fluctuation |
# | 5 | Monitor | LOW_VISIBILITY | Medium | Limited historical data |
# | 6 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | Tracking inconsistencies |
# | 7 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | External events affecting traffic |
# | 8 | Monitor | LOW_VISIBILITY | Low | Small sample size |
# | 9 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | Recent indexing changes |
# | 10 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Temporary CTR variation |
# | 11 | Monitor | LOW_VISIBILITY | Medium | Insufficient impressions |
# | 12 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | User behaviour changes |
# | 13 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Seasonal demand |
# | 14 | Monitor | LOW_VISIBILITY | Low | Data collection delays |
# | 15 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | Algorithm updates |
# | 16 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Short-term trends |
# | 17 | Monitor | LOW_VISIBILITY | Medium | Low search demand |
# | 18 | Review Metadata | HIGH_PRIORITY_REVIEW | Medium | New competing pages |
# | 19 | Refresh Content | LOW_CTR_HIGH_IMPRESSIONS | High | Temporary fluctuations |
# | 20 | Monitor | LOW_VISIBILITY | Low | Limited historical evidence |
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Weak Picks and Leakage Check
#
# Some recommendations may be weak because historical search behaviour does not always predict future performance. Seasonal trends, recently updated pages, or limited historical data may reduce the reliability of some recommendations.
#
# I confirmed that no future-window information, product flags, or label-derived features were used when creating the baseline score. The rule only uses information that would have been available at the time of the decision, making it suitable as a baseline for comparison with future ML models.## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
